# %%
# %matplotlib inline

import matplotlib.pyplot as plot
plot.rcParams['figure.figsize'] = [8, 8]

from solver import solve_one_rule
from sudoku_io import string_to_board
from sudoku_test import board_strings

# %%
board_string = board_strings['fiend']
board = string_to_board(board_string)
solve_one_rule(board, True, True)
# Out:
# Current score: 529, applying with depth == 1
# Current score: 203, applying with depth == 1
#
# Current score: 169, applying with depth == 1
# Current score: 160, applying with depth == 1
#
# Current score: 160, applying with depth == 2
# Current score: 82, applying with depth == 1
# 81
