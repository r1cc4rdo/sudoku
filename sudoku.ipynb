# %%
# %matplotlib inline

import matplotlib.pyplot as plot
plot.rcParams['figure.figsize'] = [8, 8]

import sudoku.solver_w_search
from sudoku.board_io import string_to_board, board_to_string
from sudoku.board_plot import plot_board, plot_solve

# %%
board_template = """

 8 . . | . . . | . . . 
 . . 3 | 6 . . | . . . 
 . 7 . | . 9 . | 2 . . 
-------+-------+-------
 . 5 . | . . 7 | . . . 
 . . . | . 4 5 | 7 . . 
 . . . | 1 . . | . 3 . 
-------+-------+-------
 . . 1 | . . . | . 6 8 
 . . 8 | 5 . . | . 1 . 
 . 9 . | . . . | 4 . . 

"""
board = string_to_board(board_template)
print board_to_string(board)
# Out:
# 8..........36......7..9.2...5...7.......457.....1...3...1....68..85...1..9....4..

# %%
plot_board(board)
sudoku.solver_w_search.eliminate(board)
plot_board(board, True, True)

# %%
sudoku.solver_w_search.solve = plot_solve

board = string_to_board('..36.49......5....9.......72.......6.4.....5.8.......11.......5..........9273641.')
board = sudoku.solver_w_search.solve(board)
print board_to_string(board)
# Out:
# 753614982628957134914382567275193846341268759869475321136849275487521693592736418
