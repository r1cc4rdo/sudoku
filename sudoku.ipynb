# %%
# %matplotlib inline

import matplotlib.pyplot as plot
plot.rcParams['figure.figsize'] = [8, 8]

from solver_w_search import propagate
from board_io import string_to_board
from board_plot import plot_board

# %%
board_template = """

 8 . . | . . . | . . . 
 . . 3 | 6 . . | . . . 
 . 7 . | . 9 . | 2 . . 
-------+-------+-------
 . 5 . | . . 7 | . . . 
 . . . | . 4 5 | 7 . . 
 . . . | 1 . . | . 3 . 
-------+-------+-------
 . . 1 | . . . | . 6 8 
 . . 8 | 5 . . | . 1 . 
 . 9 . | . . . | 4 . . 

"""

# %%
board = string_to_board(board_template)
board = propagate(board)
plot_board(board, True, True)
